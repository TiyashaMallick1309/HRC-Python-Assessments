# %% [markdown]
# # Pandas & Data-Preprocessing

# %% [markdown]
# ### Q.1) Create a pandas dataframe from a dictionary and display the dataframe.

# %%
import pandas as pd
d={'Name': ['John', 'Jane', 'Mike'],
        'Age': [25, 30, 35],
        'City': ['New York', 'London', 'Paris']}
df=pd.DataFrame(d)
print(df)
# Out:
#    Name  Age      City
# 0  John   25  New York
# 1  Jane   30    London
# 2  Mike   35     Paris

# %% [markdown]
# ### Q.2) Load a CSV file into a pandas dataframe and display the first 5 rows of the dataframe.

# %% [markdown]
# ###### Dataset:- https://www.kaggle.com/datasets/landlord/icecreamsales

# %%
import pandas as pd
df=pd.read_csv("icecreamsales.csv")
df.head(5)
# Out:
#    Temperature  Sales
# 0           37    292
# 1           40    228
# 2           49    324
# 3           61    376
# 4           72    440

# %% [markdown]
# ### Q.3) Load a CSV file into a pandas dataframe and display the last 5 rows of the dataframe.

# %%
import pandas as pd
df=pd.read_csv("icecreamsales.csv")
df.tail(5)
# Out:
#     Temperature  Sales
# 7            81    556
# 8            75    496
# 9            64    412
# 10           53    324
# 11           40    320

# %% [markdown]
# ### Q.4) How many rows and columns are there in the above dataframe?

# %%
print(f'Rows: {df.shape[0]}, Columns: {df.shape[1]}')
# Out:
# Rows: 12, Columns: 2

# %% [markdown]
# ### Q.5) Display all the columns of above dataframe?

# %%
print(df.columns)
# Out:
# Index(['Temperature', 'Sales'], dtype='object')

# %% [markdown]
# ### Q.6) What are the data types of each column in the dataframe?

# %%
print(f'{df.columns[0]}: {type(df.columns[0])}, {df.columns[1]}: {type(df.columns[1])}')
# Out:
# Temperature: <class 'str'>, Sales: <class 'str'>

# %% [markdown]
# ### Q.7) Check for null values in dataframe df?

# %%
df.isnull()
# Out:
#     Temperature  Sales
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# 5         False  False
# 6         False  False
# 7         False  False
# 8         False  False
# 9         False  False
# 10        False  False
# 11        False  False

# %% [markdown]
# ### Q.8) Create a new column "Total value" in a pandas dataframe that is the sum of two existing columns i.e Sale Price & Profit?

# %%
import pandas as pd
df=pd.read_csv("Computersales.csv")
df["Total value"]=df["Sale Price"]+df["Profit"]
df.head(5)
# Out:
#    Sale ID      Contact Sex  Age State Product ID Product Type  Sale Price
# 0        1  Paul Thomas   M   43    OH  M01-F0024      Desktop      479.99  \
# 1        2  Margo Simms   F   37    WV  GT13-0024      Desktop     1249.99
# 2        3    Sam Stine   M   26    PA      I3670      Desktop      649.99
# 3        4   Moe Eggert   M   35    PA      I3593       Laptop      399.99
# 4        5  Jessica Elk   F   55    PA     15M-ED       Laptop      699.99
#
#    Profit     Lead     Month  Year  Total value
# 0  143.39  Website   January  2018       623.38
# 1  230.89  Flyer 4   January  2018      1480.88
# 2  118.64  Website  February  2018       768.63
# 3   72.09  Website     March  2018       472.08
# 4   98.09  Flyer 4     March  2018       798.08

# %% [markdown]
# ### Q.9) From the above dataframe filter out  records where Age > 40?

# %%
df[df["Age"]>40]
# Out:
#     Sale ID          Contact Sex  Age State Product ID Product Type
# 0         1      Paul Thomas   M   43    OH  M01-F0024      Desktop  \
# 4         5      Jessica Elk   F   55    PA     15M-ED       Laptop
# 5         6  Sally Struthers   F   45    PA  GT13-0024      Desktop
# 6         7   Michelle Samms   F   46    OH    GA401IV       Laptop
# 8         9      Ed Klondike   M   52    OH     81TC00       Laptop
# 9        10       Phil Jones   M   56    WV  M01-F0024      Desktop
# 10       11       Rick James   M   49    PA    GA401IV       Laptop
# 11       12         Sue Etna   F   54    OH  GT13-0024      Desktop
# 12       13       Jason Case   M   57    PA     81TC00       Laptop
# 13       14     Doug Johnson   M   51    PA      I3670      Desktop
# 14       15       Andy Sands   M   56    OH    MY2J2LL       Tablet
# 15       16      Kim Collins   F   49    PA      I3593       Laptop
# 16       17     Edna Sanders   F   46    OH     15M-ED       Laptop
# ...

# %% [markdown]
# ### Q.10) Drop State column from dataframe df?

# %%
df.drop("State",axis=1)
# Out:
#     Sale ID          Contact Sex  Age Product ID Product Type  Sale Price
# 0         1      Paul Thomas   M   43  M01-F0024      Desktop      479.99  \
# 1         2      Margo Simms   F   37  GT13-0024      Desktop     1249.99
# 2         3        Sam Stine   M   26      I3670      Desktop      649.99
# 3         4       Moe Eggert   M   35      I3593       Laptop      399.99
# 4         5      Jessica Elk   F   55     15M-ED       Laptop      699.99
# 5         6  Sally Struthers   F   45  GT13-0024      Desktop     1249.99
# 6         7   Michelle Samms   F   46    GA401IV       Laptop     1349.99
# 7         8     Mick Roberts   M   23    MY2J2LL       Tablet      999.99
# 8         9      Ed Klondike   M   52     81TC00       Laptop      649.99
# 9        10       Phil Jones   M   56  M01-F0024      Desktop      479.99
# 10       11       Rick James   M   49    GA401IV       Laptop     1349.99
# 11       12         Sue Etna   F   54  GT13-0024      Desktop     1249.99
# ...

# %% [markdown]
# ### Q.11) Read a csv file and display the information about the dataframe?
# #### Dataset:- https://www.kaggle.com/datasets/rohitsahoo/sales-forecasting

# %%
import pandas as pd
df=pd.read_csv("train.csv")
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# ### Q.12) Convert the datatype of column Ship Date from object to datetime?

# %%
df['Ship Date']= pd.to_datetime(df['Ship Date'])

# %% [markdown]
# ### Q.13) Convert the datatype of column Sales from float to int?

# %%
df["Sales"]=df["Sales"].astype(int)

# %% [markdown]
# ### Q.14) Drop any rows with null values?

# %%
df.dropna()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class  \
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City
# ...

# %% [markdown]
# ### Q.15)  Display the total sales for each region from the above dataframe?

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    492646.9132
# East       669518.7260
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %% [markdown]
# ### Q.16) How many unique categories of product are there in the above dataframe?

# %%
print(df["Category"].unique())
# Out:
# ['Furniture' 'Office Supplies' 'Technology']

# %% [markdown]
# ### Q.17) How can you replace all missing values in the 'Sales' column with the mean value of that column?
#
# ##### Note:- Let us assume there is null values in sales column

# %%
df.fillna(df.mean)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class  \
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City
# ...

# %% [markdown]
# ### Q.18) How can you select all rows and columns of a DataFrame using loc?

# %%
df.loc[:]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class  \
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City
# ...

# %% [markdown]
# ### Q.19) How can you rename a Sub-Category column to sub Category in  DataFrame df?

# %%
df.rename(columns={'Sub-Category': 'sub Category'})
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class  \
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City
# ...

# %% [markdown]
# ### Q.20) Display all records from dataframe df where city is Chicago?

# %%
df[df['City']=='Chicago']
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode
# 66        67  US-2016-164175  30/04/2016  05/05/2016  Standard Class  \
# 84        85  US-2018-119662  13/11/2018  16/11/2018     First Class
# 99       100  CA-2017-158568  29/08/2017  02/09/2017  Standard Class
# 100      101  CA-2017-158568  29/08/2017  02/09/2017  Standard Class
# 101      102  CA-2017-158568  29/08/2017  02/09/2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 9747    9748  US-2015-140914  11/11/2015  15/11/2015  Standard Class
# 9748    9749  US-2015-140914  11/11/2015  15/11/2015  Standard Class
# 9750    9751  CA-2017-113390  11/10/2017  15/10/2017  Standard Class
# 9751    9752  CA-2017-113390  11/10/2017  15/10/2017  Standard Class
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
#
#      Customer ID       Customer Name      Segment        Country     City
# ...
