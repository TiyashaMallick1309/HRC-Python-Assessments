# %% [markdown]
# # Feature Engineering & Feature Selection Questions

# %% [markdown]
# ### Based on computersales datset answer the below questions

# %%
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/Computersales.csv')
df.head()
# Out:
#    Sale ID      Contact Sex  Age State Product ID Product Type  Sale Price
# 0        1  Paul Thomas   M   43    OH  M01-F0024      Desktop      479.99  \
# 1        2  Margo Simms   F   37    WV  GT13-0024      Desktop     1249.99
# 2        3    Sam Stine   M   26    PA      I3670      Desktop      649.99
# 3        4   Moe Eggert   M   35    PA      I3593       Laptop      399.99
# 4        5  Jessica Elk   F   55    PA     15M-ED       Laptop      699.99
#
#    Profit     Lead     Month  Year
# 0  143.39  Website   January  2018
# 1  230.89  Flyer 4   January  2018
# 2  118.64  Website  February  2018
# 3   72.09  Website     March  2018
# 4   98.09  Flyer 4     March  2018

# %% [markdown]
# ### Q.1) Create a new feature i.e original_price that is the difference between two existing features (Sale Price and Profit)?

# %%
# Sale Price - Profit
df['original_price'] = df["Sale Price"] - df['Profit']
df["original_price"]
# Out:
# 0      336.60
# 1     1019.10
# 2      531.35
# 3      327.90
# 4      601.90
# 5     1019.10
# 6     1169.65
# 7      853.30
# 8      527.65
# 9      336.60
# 10    1169.65
# 11    1019.10
# 12     527.65
# 13     531.35
# 14     853.30
# 15     327.90
# 16     601.90
# 17     853.30
# 18     327.90
# 19     527.65
# 20     336.60
# 21    1169.65
# 22     527.65
# 23     906.90
# 24     531.35
# 25     906.90
# 26     906.90
# 27     601.90
# 28    1169.65
# 29     336.60
# 30    1169.65
# 31    1019.10
# 32     327.90
# 33     601.90
# 34     853.30
# 35     527.65
# 36     336.60
# 37    1169.65
# 38     327.90
# Name: original_price, dtype: float64

# %% [markdown]
# ### Q.2) Create a new binary feature to indicate whether or not a sale was made via website?

# %%
website_sales_value = 'Website'

df['Website_Sale'] = (df['Lead'] == website_sales_value).astype(int)
df['Website_Sale']
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0
# 5     0
# 6     0
# 7     1
# 8     0
# 9     0
# 10    0
# 11    0
# 12    0
# 13    1
# 14    0
# 15    0
# 16    0
# 17    1
# 18    0
# 19    1
# 20    0
# 21    1
# 22    1
# 23    0
# 24    0
# 25    0
# 26    1
# 27    0
# 28    0
# 29    0
# 30    0
# 31    0
# 32    0
# 33    0
# 34    1
# 35    1
# 36    0
# 37    1
# 38    1
# Name: Website_Sale, dtype: int32

# %% [markdown]
# ### Q.3) Write a code to perform one hot encoding on Product Type column of computersales dataset.

# %%
# performing one hot encoding using pandas get_dummies() function
encoded_df = pd.get_dummies(df, columns=['Product Type'], prefix='Product')
print(encoded_df)
# Out:
#     Sale ID          Contact Sex  Age State Product ID  Sale Price  Profit
# 0         1      Paul Thomas   M   43    OH  M01-F0024      479.99  143.39  \
# 1         2      Margo Simms   F   37    WV  GT13-0024     1249.99  230.89
# 2         3        Sam Stine   M   26    PA      I3670      649.99  118.64
# 3         4       Moe Eggert   M   35    PA      I3593      399.99   72.09
# 4         5      Jessica Elk   F   55    PA     15M-ED      699.99   98.09
# 5         6  Sally Struthers   F   45    PA  GT13-0024     1249.99  230.89
# 6         7   Michelle Samms   F   46    OH    GA401IV     1349.99  180.34
# 7         8     Mick Roberts   M   23    OH    MY2J2LL      999.99  146.69
# 8         9      Ed Klondike   M   52    OH     81TC00      649.99  122.34
# 9        10       Phil Jones   M   56    WV  M01-F0024      479.99  143.39
# 10       11       Rick James   M   49    PA    GA401IV     1349.99  180.34
# ...

# %% [markdown]
# ### Q.4) Write a code to perform label encoding on State column of computersales dataset.

# %%
# performing label encoding 
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['State_Encoded'] = encoder.fit_transform(df['State'])
print(df)
# Out:
#     Sale ID          Contact Sex  Age State Product ID Product Type
# 0         1      Paul Thomas   M   43    OH  M01-F0024      Desktop  \
# 1         2      Margo Simms   F   37    WV  GT13-0024      Desktop
# 2         3        Sam Stine   M   26    PA      I3670      Desktop
# 3         4       Moe Eggert   M   35    PA      I3593       Laptop
# 4         5      Jessica Elk   F   55    PA     15M-ED       Laptop
# 5         6  Sally Struthers   F   45    PA  GT13-0024      Desktop
# 6         7   Michelle Samms   F   46    OH    GA401IV       Laptop
# 7         8     Mick Roberts   M   23    OH    MY2J2LL       Tablet
# 8         9      Ed Klondike   M   52    OH     81TC00       Laptop
# 9        10       Phil Jones   M   56    WV  M01-F0024      Desktop
# 10       11       Rick James   M   49    PA    GA401IV       Laptop
# 11       12         Sue Etna   F   54    OH  GT13-0024      Desktop
# 12       13       Jason Case   M   57    PA     81TC00       Laptop
# ...

# %% [markdown]
# ### Q.5) Write a code to perform ordinal encoding on Lead column?

# %%
# performing ordinal encoding 
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Flyer 3', 'Email', 'Flyer 4', 'Website', 'Flyer 1', 'Flyer 2']])
df['Lead_Encoded'] = encoder.fit_transform(df[['Lead']])
print(df)
# Out:
#     Sale ID          Contact Sex  Age State Product ID Product Type
# 0         1      Paul Thomas   M   43    OH  M01-F0024      Desktop  \
# 1         2      Margo Simms   F   37    WV  GT13-0024      Desktop
# 2         3        Sam Stine   M   26    PA      I3670      Desktop
# 3         4       Moe Eggert   M   35    PA      I3593       Laptop
# 4         5      Jessica Elk   F   55    PA     15M-ED       Laptop
# 5         6  Sally Struthers   F   45    PA  GT13-0024      Desktop
# 6         7   Michelle Samms   F   46    OH    GA401IV       Laptop
# 7         8     Mick Roberts   M   23    OH    MY2J2LL       Tablet
# 8         9      Ed Klondike   M   52    OH     81TC00       Laptop
# 9        10       Phil Jones   M   56    WV  M01-F0024      Desktop
# 10       11       Rick James   M   49    PA    GA401IV       Laptop
# 11       12         Sue Etna   F   54    OH  GT13-0024      Desktop
# 12       13       Jason Case   M   57    PA     81TC00       Laptop
# ...

# %% [markdown]
# ### Q.6)  Create a new feature Total_contact_profit to capture the total profit made by each Contact i.e customer in the dataset and store in a new df?

# %%
new_df = pd.DataFrame() 
grouped_df = df.groupby('Contact')['Profit'].sum()
new_df['Contact'] = grouped_df.index
new_df['Total_contact_profit'] = grouped_df.values
print(new_df)
# Out:
#             Contact  Total_contact_profit
# 0        Andy Sands                146.69
# 1      Doug Johnson                479.32
# 2       Ed Klondike                265.43
# 3      Edna Sanders                196.18
# 4        Jason Case                409.12
# 5       Jessica Elk                278.43
# 6       Kim Collins                144.18
# 7       Margo Simms                373.98
# 8    Michelle Samms                592.36
# 9      Mick Roberts                361.87
# 10       Moe Eggert                242.27
# 11      Paul Thomas                265.73
# 12       Phil Jones                286.78
# 13       Rick James                360.68
# 14  Sally Struthers                475.57
# 15        Sam Stine                118.64
# 16         Sue Etna                461.78

# %% [markdown]
# ### Q.7) Perform feature scaling on a numerical feature Age using min-max normalization?

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() 
df['Age_normalized'] = scaler.fit_transform(df[['Age']])  
print(df['Age_normalized'])
# Out:
# 0     0.588235
# 1     0.411765
# 2     0.088235
# 3     0.352941
# 4     0.941176
# 5     0.647059
# 6     0.676471
# 7     0.000000
# 8     0.852941
# 9     0.970588
# 10    0.764706
# 11    0.911765
# 12    1.000000
# 13    0.823529
# 14    0.970588
# 15    0.764706
# 16    0.676471
# 17    0.676471
# 18    0.000000
# 19    0.647059
# 20    1.000000
# 21    0.823529
# 22    0.588235
# 23    0.411765
# 24    0.676471
# 25    0.000000
# 26    0.852941
# 27    0.352941
# 28    0.941176
# 29    0.970588
# 30    0.764706
# 31    0.911765
# 32    0.764706
# 33    0.676471
# 34    0.676471
# 35    0.647059
# 36    1.000000
# 37    0.823529
# 38    0.352941
# Name: Age_normalized, dtype: float64

# %% [markdown]
# ### Q.8)  Given a Pandas DataFrame with a "date" column, how can you extract the year, month, and day as separate columns?

# %%
import pandas as pd

df = pd.DataFrame({'date': ['2022-05-15', '2022-05-16', '2022-05-17','2022-05-18', '2022-05-19', '2022-05-20']})

df['date'] = pd.to_datetime(df['date'])

df
# Out:
#         date
# 0 2022-05-15
# 1 2022-05-16
# 2 2022-05-17
# 3 2022-05-18
# 4 2022-05-19
# 5 2022-05-20

# %% [markdown]
# ### Solution:-

# %%
# extracting year,moth & day feature
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
print(df)
# Out:
#         date  year  month  day
# 0 2022-05-15  2022      5   15
# 1 2022-05-16  2022      5   16
# 2 2022-05-17  2022      5   17
# 3 2022-05-18  2022      5   18
# 4 2022-05-19  2022      5   19
# 5 2022-05-20  2022      5   20

# %% [markdown]
# ### Q.9) Given a Pandas DataFrame with a "text" column, how can you create a new column that contains the number of words in each text entry?

# %%
import pandas as pd

df = pd.DataFrame({'text': ['This is a sample sentence.', 'Another sentence.', 'And a third.']})

# %% [markdown]
# ### Solution:-

# %%
df['word_count'] = df['text'].str.split().str.len()
df['word_count']
# Out:
# 0    5
# 1    2
# 2    3
# Name: word_count, dtype: int64

# %% [markdown]
# ### Q.10) Perform encoding using pandas get_dummies() function?

# %%
# Given dataframe

import pandas as pd


df = pd.DataFrame({'color': ['red', 'blue', 'green', 'red', 'green']})
df
# Out:
#    color
# 0    red
# 1   blue
# 2  green
# 3    red
# 4  green

# %% [markdown]
# ### Solution:-

# %%
encoded_df = pd.get_dummies(df['color'])
print(encoded_df)
# Out:
#     blue  green    red
# 0  False  False   True
# 1   True  False  False
# 2  False   True  False
# 3  False  False   True
# 4  False   True  False

# %% [markdown]
# ### Q.11) Perform correlation-based feature selection using Pearson correlation on  iris dataset?

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load the iris dataset
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Solution:-

# %%
label_encoder = LabelEncoder()
iris['species_encoded'] = label_encoder.fit_transform(iris['species'])
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa  \
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_encoded
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...

# %%
features = iris.drop(['species'], axis=1)
# Calculate the Pearson correlation coefficients
correlation_matrix = features.corr()
target_correlation = abs(correlation_matrix['species_encoded'])
selected_features = target_correlation[target_correlation > 0.5]
print(selected_features)
# Out:
# sepal_length       0.782561
# petal_length       0.949035
# petal_width        0.956547
# species_encoded    1.000000
# Name: species_encoded, dtype: float64
